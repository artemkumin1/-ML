# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import pandas as pd

# %% [markdown]
# #### Описание данных
#
# В папке Dat (https://github.com/hse-ds/iad-intro-ds/blob/master/2023/homeworks/Data.zip) находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
# !wget https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip
# Out:
# --2024-02-12 18:08:54--  https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2023/homeworks/Data.zip [following]
# --2024-02-12 18:08:54--  https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2023/homeworks/Data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16727 (16K) [application/zip]
# Saving to: ‘Data.zip’
#
# Data.zip            100%[===================>]  16.33K  --.-KB/s    in 0.001s
#
# 2024-02-12 18:08:55 (16.1 MB/s) - ‘Data.zip’ saved [16727/16727]

# %%
# !unzip /content/Data.zip
# Out:
# Archive:  /content/Data.zip
#    creating: Data/
#   inflating: Data/Students_info_0.csv
#   inflating: Data/Students_info_1.csv
#   inflating: Data/Students_info_2.csv
#   inflating: Data/Students_info_3.csv
#   inflating: Data/Students_info_4.csv
#   inflating: Data/Students_info_5.csv
#   inflating: Data/Students_info_6.csv
#   inflating: Data/Students_info_7.csv
#   inflating: Data/Students_info_8.csv
#   inflating: Data/Students_info_9.csv
#   inflating: Data/Students_marks_0.csv
#   inflating: Data/Students_marks_1.csv
#   inflating: Data/Students_marks_2.csv
#   inflating: Data/Students_marks_3.csv
#   inflating: Data/Students_marks_4.csv
#   inflating: Data/Students_marks_5.csv
#   inflating: Data/Students_marks_6.csv
#   inflating: Data/Students_marks_7.csv
#   inflating: Data/Students_marks_8.csv
#   inflating: Data/Students_marks_9.csv

# %%
infototal=[]
markstotal=[]

for i in range(10):
  info=pd.read_csv(f'/content/Data/Students_info_{i}.csv', delimiter=',')
  marks=pd.read_csv(f'/content/Data/Students_marks_{i}.csv', delimiter=',')
  infototal.append(info)
  markstotal.append(marks)

result1=pd.concat(infototal)
result2=pd.concat(markstotal)
df=pd.merge(result1,result2)
df
# Out:
#      index  gender race/ethnicity parental level of education         lunch  \
# 0        0  female        group B           bachelor's degree      standard
# 1        1  female        group C                some college      standard
# 2        2  female        group B             master's degree      standard
# 3        3    male        group A          associate's degree  free/reduced
# 4        4    male        group C                some college      standard
# ..     ...     ...            ...                         ...           ...
# 995    995  female        group E             master's degree      standard
# 996    996    male        group C                 high school  free/reduced
# 997    997  female        group C                 high school  free/reduced
# 998    998  female        group D                some college      standard
# 999    999  female        group D                some college  free/reduced
#
# ...

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
df=df.drop(['index'], axis=1)
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course   group  math score  reading score  writing score
# 0                    none  group1          72             72             74
# 1               completed  group1          69             90             88
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %%
df.describe().drop(['count','25%','50%','75%'],axis=0)
# Out:
#       math score  reading score  writing score
# mean    66.08900      69.169000      68.054000
# std     15.16308      14.600192      15.195657
# min      0.00000      17.000000      10.000000
# max    100.00000     100.000000     100.000000

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
df.isnull().any().any()
# Out:
# False

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
df[['math score', 'reading score','writing score']].mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
df.groupby('test preparation course').mean()
# мы видим зависимость между результатами экзамнов и прохожднием курса для подготовки. Студенты проходившие
#курс  имеют более высокий средний бал (минимум на 5 баллов больше (в математике))
# Out:
# <ipython-input-10-a1123bf472d7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('test preparation course').mean()
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
df['lunch'].unique().tolist()
# Out:
# ['standard', 'free/reduced']

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df.rename(columns = {'parental level of education':'education', 'test preparation course':'test preparation'}, inplace = True )
df
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 0    female        group B   bachelor's degree      standard             none
# 1    female        group C        some college      standard        completed
# 2    female        group B     master's degree      standard             none
# 3      male        group A  associate's degree  free/reduced             none
# 4      male        group C        some college      standard             none
# ..      ...            ...                 ...           ...              ...
# 995  female        group E     master's degree      standard        completed
# 996    male        group C         high school  free/reduced             none
# 997  female        group C         high school  free/reduced        completed
# 998  female        group D        some college      standard        completed
# 999  female        group D        some college  free/reduced             none
#
# ...

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
(df['math score']>=passmark).sum() / (df['math score']).count()
# Out:
# 0.865

# %%
((df['test preparation'] == 'completed') & (df['math score'] >=passmark)).sum() / (df['test preparation']=='completed').sum()
# Out:
# 0.9217877094972067

# %%
((df['test preparation'] == 'none') & (df['math score'] <passmark) & (df['gender']=='female')).sum() / ((df['test preparation'] == 'none') & (df['gender']=='female')).sum()
# Out:
# 0.20958083832335328

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
# %%time
(df.groupby('race/ethnicity').mean())[['reading score']].reset_index()
# Out:
# CPU times: user 4.72 ms, sys: 948 µs, total: 5.67 ms
# Wall time: 7.68 ms
# <timed eval>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   race/ethnicity  reading score
# 0        group A      64.674157
# 1        group B      67.352632
# 2        group C      69.103448
# 3        group D      70.030534
# 4        group E      73.028571

# %%
# %%time
(df.groupby('education').min())['writing score'].reset_index()
# Out:
# CPU times: user 12.8 ms, sys: 0 ns, total: 12.8 ms
# Wall time: 17.6 ms
#             education  writing score
# 0  associate's degree             35
# 1   bachelor's degree             38
# 2         high school             15
# 3     master's degree             46
# 4        some college             19
# 5    some high school             10

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
# %%time
for group,group_data in df.groupby('race/ethnicity'):
  print(group,group_data['reading score'].mean())

# используя groupby
# Out:
# group A 64.67415730337079
# group B 67.35263157894737
# group C 69.10344827586206
# group D 70.03053435114504
# group E 73.02857142857142
# CPU times: user 4.18 ms, sys: 0 ns, total: 4.18 ms
# Wall time: 3.84 ms

# %%
# %%time
for i in df['race/ethnicity'].unique():
  a=df[df['race/ethnicity']==i][['reading score']].mean()
  print(a,i)
  # не используя groupby
# Out:
# reading score    67.352632
# dtype: float64 group B
# reading score    69.103448
# dtype: float64 group C
# reading score    64.674157
# dtype: float64 group A
# reading score    70.030534
# dtype: float64 group D
# reading score    73.028571
# dtype: float64 group E
# CPU times: user 18.8 ms, sys: 0 ns, total: 18.8 ms
# Wall time: 19 ms

# %%
# %%time
for group, group_data in df.groupby('education'):
  print(group,group_data['writing score'].min())

#используя groupby
# Out:
# associate's degree 35
# bachelor's degree 38
# high school 15
# master's degree 46
# some college 19
# some high school 10
# CPU times: user 9.74 ms, sys: 134 µs, total: 9.88 ms
# Wall time: 14.4 ms

# %%
for i in df['education'].unique():
  a=df[df['education']==i][['writing score']].min()
  print(a,i)
#не используя groupby
# Out:
# writing score    38
# dtype: int64 bachelor's degree
# writing score    19
# dtype: int64 some college
# writing score    46
# dtype: int64 master's degree
# writing score    35
# dtype: int64 associate's degree
# writing score    15
# dtype: int64 high school
# writing score    10
# dtype: int64 some high school

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
a=df[['math score', 'reading score', 'writing score','education','gender']]
grouped = pd.pivot_table(a,index=['education', 'gender'])
grouped
# Out:
#                            math score  reading score  writing score
# education          gender
# associate's degree female   65.250000      74.120690      74.000000
#                    male     70.764151      67.433962      65.405660
# bachelor's degree  female   68.349206      77.285714      78.380952
#                    male     70.581818      68.090909      67.654545
# high school        female   59.351064      68.202128      66.691489
#                    male     64.705882      61.480392      58.539216
# master's degree    female   66.500000      76.805556      77.638889
#                    male     74.826087      73.130435      72.608696
# some college       female   65.406780      73.550847      74.050847
#                    male     69.009259      64.990741      63.148148
# some high school   female   59.296703      69.109890      68.285714
#                    male     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %%
df['Math_PassStatus'] = df['math score'].apply(lambda x: 'P' if x >=passmark else 'F')
df['Reading_PassStatus'] = df['reading score'].apply(lambda x: 'P' if x >=passmark else 'F')
df['Writing_PassStatus'] = df['writing score'].apply(lambda x: 'P' if x >=passmark else 'F')
df
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 0    female        group B   bachelor's degree      standard             none
# 1    female        group C        some college      standard        completed
# 2    female        group B     master's degree      standard             none
# 3      male        group A  associate's degree  free/reduced             none
# 4      male        group C        some college      standard             none
# ..      ...            ...                 ...           ...              ...
# 995  female        group E     master's degree      standard        completed
# 996    male        group C         high school  free/reduced             none
# 997  female        group C         high school  free/reduced        completed
# 998  female        group D        some college      standard        completed
# 999  female        group D        some college  free/reduced             none
#
# ...

# %%
df['Math_PassStatus'].value_counts()
# Out:
# P    865
# F    135
# Name: Math_PassStatus, dtype: int64

# %%
df['Reading_PassStatus'].value_counts()
# Out:
# P    910
# F     90
# Name: Reading_PassStatus, dtype: int64

# %%
df['Writing_PassStatus'].value_counts()
# Out:
# P    886
# F    114
# Name: Writing_PassStatus, dtype: int64

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
df['OverAll_PassStatus']=df[['reading score','math score','reading score']].apply(lambda x: 'P' if x[0] >=passmark and x[1]>=passmark and x[2]>=passmark  else 'F',axis=1)
df
#используя лямбду
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 0    female        group B   bachelor's degree      standard             none
# 1    female        group C        some college      standard        completed
# 2    female        group B     master's degree      standard             none
# 3      male        group A  associate's degree  free/reduced             none
# 4      male        group C        some college      standard             none
# ..      ...            ...                 ...           ...              ...
# 995  female        group E     master's degree      standard        completed
# 996    male        group C         high school  free/reduced             none
# 997  female        group C         high school  free/reduced        completed
# 998  female        group D        some college      standard        completed
# 999  female        group D        some college  free/reduced             none
#
# ...

# %%
# import numpy as np
# df['OverAll_PassStatus']=np.where((df['math score']>=passmark) & (df['reading score']>=passmark) & (df['writing score']>=passmark),'P','F')
# df
# #используя numpy

# %%
df['OverAll_PassStatus'].value_counts()[0]
# Out:
# 834

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
def GetGrade(average_mark):
  if (average_mark)/3 >=90:
    return 'A'
  elif 80<=(average_mark)/3 <=90:
    return 'B'
  elif 70<=(average_mark)/3 <80:
    return 'C'
  elif 60<=(average_mark)/3 <70:
    return 'D'
  elif 50<=(average_mark)/3 <60:
    return 'E'
  else:
    return 'F'

# %%
average_mark=df['math score']+df['reading score']+df['writing score']

# %%
df['Grade']=average_mark.apply(GetGrade)
df
# Out:
#      gender race/ethnicity           education         lunch test preparation  \
# 0    female        group B   bachelor's degree      standard             none
# 1    female        group C        some college      standard        completed
# 2    female        group B     master's degree      standard             none
# 3      male        group A  associate's degree  free/reduced             none
# 4      male        group C        some college      standard             none
# ..      ...            ...                 ...           ...              ...
# 995  female        group E     master's degree      standard        completed
# 996    male        group C         high school  free/reduced             none
# 997  female        group C         high school  free/reduced        completed
# 998  female        group D        some college      standard        completed
# 999  female        group D        some college  free/reduced             none
#
# ...

# %%
df['Grade'].value_counts()
# Out:
# C    261
# D    256
# E    182
# B    146
# F    103
# A     52
# Name: Grade, dtype: int64
